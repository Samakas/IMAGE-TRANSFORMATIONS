# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('dog.jpg')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  
plt.imshow(image_rgb)
plt.title("Orginal image")
# plt.axis('off')
# Out:
# Text(0.5, 1.0, 'Orginal image')

# %%
# Image Translation
rows, cols, _ = image.shape
M_translate = np.float32([[1, 0, 30], [0, 1, 60]])  # Translate by (30, 60) pixels
translated_image = cv2.warpAffine(image_rgb, M_translate, (cols, rows))
plt.imshow(translated_image)
plt.title("Translated Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(288.5), np.float64(174.5), np.float64(-0.5))

# %%
#Image Scaling
scaled_image = cv2.resize(image_rgb, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_LINEAR)  # Scale by 1.5x
plt.imshow(scaled_image)
plt.title("Scaled Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(433.5), np.float64(261.5), np.float64(-0.5))

# %%
#Image shearing
M_shear = np.float32([[1, 0.5, 0], [0.5, 1, 0]])  # Shear with factor 0.5
sheared_image = cv2.warpAffine(image_rgb, M_shear, (int(cols * 1.5), int(rows * 1.5)))
plt.imshow(sheared_image)
plt.title("Sheared Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(432.5), np.float64(261.5), np.float64(-0.5))

# %%
#Image Reflection
reflected_image = cv2.flip(image_rgb, 1)  # Horizontal reflection (flip along y-axis)
plt.imshow(reflected_image)
plt.title("Reflected Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(288.5), np.float64(174.5), np.float64(-0.5))

# %%
#Image Rotation
M_rotate = cv2.getRotationMatrix2D((cols / 2, rows / 2), 90, 1)  # Rotate by 90 degrees
rotated_image = cv2.warpAffine(image_rgb, M_rotate, (cols, rows))
plt.imshow(rotated_image)
plt.title("Rotated Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(288.5), np.float64(174.5), np.float64(-0.5))

# %%
#Image Cropping
cropped_image = image_rgb[5:150, 15:200]  # Crop a portion of the image
plt.figure(figsize=(4, 4))
plt.imshow(cropped_image)
plt.title("Cropped Image")
plt.axis('off')
plt.show()
